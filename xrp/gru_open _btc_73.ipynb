# %%
import pandas as pd
import datetime as dt
import numpy as np

from csv import writer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU
from keras.models import load_model

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('xrp_open.csv')
print(df)
# Out:
#       Unnamed: 0 formatted_date      high       low      open     close  \
# 0              0     2019-01-01  0.364771  0.350402  0.365675  0.364771
# 1              1     2019-01-02  0.378021  0.359574  0.374505  0.375243
# 2              2     2019-01-03  0.374505  0.357675  0.359753  0.360224
# 3              3     2019-01-04  0.364642  0.352785  0.356347  0.356747
# 4              4     2019-01-05  0.361069  0.353987  0.354750  0.355275
# ...          ...            ...       ...       ...       ...       ...
# 1515        1515     2023-02-24  0.390547  0.374133  0.378507  0.378477
# 1516        1516     2023-02-25  0.379419  0.372250  0.378085  0.378085
# 1517        1517     2023-02-26  0.380606  0.375420  0.378005  0.378041
# 1518        1518     2023-02-27  0.380042  0.372158  0.379121  0.379115
# 1519        1519     2023-02-28  0.382433  0.373027  0.377133  0.377150
#
#           volume  adjclose
# 0      449347622  0.364771
# 1      543216669  0.375243
# 2      438873803  0.360224
# 3      450633876  0.356747
# 4      452090239  0.355275
# ...          ...       ...
# 1515   953355531  0.378477
# 1516   552223148  0.378085
# 1517   441815645  0.378041
# 1518  1049508853  0.379115
# 1519  1000693267  0.377150
#
# [1520 rows x 8 columns]

# %%
# Process data
df['H-L'] = df['high'] - df['low']
# df['O-C'] = df['open'] - df['open']
ma_1 = 7
ma_2 = 14
ma_3 = 21
df[f'SMA_{ma_1}'] = df['open'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['open'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['open'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['open'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['open'].rolling(window=ma_3).std()
df.dropna(inplace=True)

# df.to_csv("/BOOSTING/bitcoin_processed_open.csv")
df
# Out:
#       Unnamed: 0 formatted_date      high       low      open     close  \
# 20            20     2019-01-21  0.322593  0.317439  0.321078  0.320790
# 21            21     2019-01-22  0.321078  0.313455  0.319566  0.319491
# 22            22     2019-01-23  0.320303  0.314923  0.316416  0.316492
# 23            23     2019-01-24  0.318896  0.314433  0.317859  0.317598
# 24            24     2019-01-25  0.319069  0.313824  0.317260  0.317165
# ...          ...            ...       ...       ...       ...       ...
# 1515        1515     2023-02-24  0.390547  0.374133  0.378507  0.378477
# 1516        1516     2023-02-25  0.379419  0.372250  0.378085  0.378085
# 1517        1517     2023-02-26  0.380606  0.375420  0.378005  0.378041
# 1518        1518     2023-02-27  0.380042  0.372158  0.379121  0.379115
# 1519        1519     2023-02-28  0.382433  0.373027  0.377133  0.377150
#
#           volume  adjclose       H-L     SMA_7    SMA_14    SMA_21      SD_7  \
# 20     363940431  0.320790  0.005154  0.326430  0.333398  0.343423  0.004046
# 21     434125854  0.319491  0.007623  0.325376  0.330090  0.341227  0.004784
# 22     375671478  0.316492  0.005380  0.323480  0.326158  0.338461  0.005382
# 23     344960253  0.317598  0.004463  0.321860  0.325199  0.336466  0.005072
# 24     360076505  0.317165  0.005245  0.320654  0.324074  0.334605  0.005010
# ...          ...       ...       ...       ...       ...       ...       ...
# 1515   953355531  0.378477  0.016414  0.390655  0.387824  0.390458  0.006728
# 1516   552223148  0.378085  0.007169  0.388296  0.387403  0.388878  0.007907
# 1517   441815645  0.378041  0.005186  0.387100  0.387600  0.387880  0.008825
# 1518  1049508853  0.379115  0.007884  0.384329  0.388137  0.387227  0.007603
# 1519  1000693267  0.377150  0.009406  0.382218  0.387763  0.385954  0.007187
#
#          SD_21
# 20    0.019639
# 21    0.019605
# 22    0.018754
# 23    0.018603
# 24    0.018470
# ...        ...
# 1515  0.010027
# 1516  0.009161
# 1517  0.009149
# 1518  0.009266
# 1519  0.008684
#
# [1500 rows x 14 columns]

# %%
pre_day =7
scala_x = MinMaxScaler(feature_range=(0,1))
scala_y = MinMaxScaler(feature_range=(0,1))
cols_x = ['high','low','close','H-L', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['open']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))

x_total = []
y_total = []

for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])

# test_size = (int)(len(scaled_data_y) * 0.2)
# print(test_size)

# x_train = np.array(x_total[:len(x_total)])
# # x_test = np.array(x_total[len(x_total)-test_size:])
# y_train = np.array(y_total[:len(y_total)])
# # y_test = np.array(y_total[len(y_total)-test_size:])

test_size = (int)(len(scaled_data_y) * 0.3)
print(test_size)

x_train = np.array(x_total[:len(x_total)-test_size])
x_test = np.array(x_total[len(x_total)-test_size:])
y_train = np.array(y_total[:len(y_total)-test_size])
y_test = np.array(y_total[len(y_total)-test_size:])



print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# 450
# (1043, 7, 9) (1043, 1) (450, 7, 9) (450, 1)

# %%
# Build model
model = Sequential()

model.add(GRU(units=60, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=120, steps_per_epoch=40, use_multiprocessing=True)
# model.save("../../model/BOOSTING/GRU_boosting_open.h5")
# Out:
# Epoch 1/120
# 40/40 [==============================] - 51s 19ms/step - loss: 0.0135
# Epoch 2/120
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0054
# Epoch 3/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0046
# Epoch 4/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0042
# Epoch 5/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0047
# Epoch 6/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0039
# Epoch 7/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0042
# Epoch 8/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0043
# Epoch 9/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0030
# Epoch 10/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0031
# Epoch 11/120
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0026
# Epoch 12/120
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0030
# Epoch 13/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0026
# Epoch 14/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0031
# Epoch 15/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0029
# Epoch 16/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0025
# Epoch 17/120
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0025
# Epoch 18/120
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0025
# Epoch 19/120
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0020
# Epoch 20/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0025
# Epoch 21/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0025
# Epoch 22/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0020
# Epoch 23/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0028
# Epoch 24/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0019
# Epoch 25/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0020
# Epoch 26/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0022
# Epoch 27/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0020
# Epoch 28/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0017
# Epoch 29/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0022
# Epoch 30/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0022
# Epoch 31/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0019
# Epoch 32/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0019
# Epoch 33/120
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018
# Epoch 34/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0018
# Epoch 35/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0022
# Epoch 36/120
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018
# Epoch 37/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0015
# Epoch 38/120
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0019
# Epoch 39/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0019
# Epoch 40/120
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0018
# Epoch 41/120
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018
# Epoch 42/120
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0015
# Epoch 43/120
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017
# Epoch 44/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0020
# Epoch 45/120
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0019
# Epoch 46/120
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0014
# Epoch 47/120
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0015
# Epoch 48/120
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0015
# Epoch 49/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0015
# Epoch 50/120
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0017
# Epoch 51/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0014
# Epoch 52/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0018
# Epoch 53/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0016
# Epoch 54/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0016
# Epoch 55/120
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0014
# Epoch 56/120
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0015
# Epoch 57/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0015
# Epoch 58/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0015
# Epoch 59/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0014
# Epoch 60/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0014
# Epoch 61/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0015
# Epoch 62/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0016
# Epoch 63/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0013
# Epoch 64/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 65/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0014
# Epoch 66/120
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 67/120
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 68/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0014
# Epoch 69/120
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 70/120
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 71/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 72/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 73/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0016
# Epoch 74/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0014
# Epoch 75/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 76/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0012
# Epoch 77/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0014
# Epoch 78/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 79/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0015
# Epoch 80/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 81/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 82/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 83/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 84/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0015
# Epoch 85/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0014
# Epoch 86/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 87/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0015
# Epoch 88/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 89/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 90/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0014
# Epoch 91/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0014
# Epoch 92/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 93/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 94/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 95/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0015
# Epoch 96/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 97/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 98/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0013
# Epoch 99/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0013
# Epoch 100/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 101/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0013
# Epoch 102/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0012
# Epoch 103/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0014
# Epoch 104/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 105/120
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 106/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0012
# Epoch 107/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0011
# Epoch 108/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0014
# Epoch 109/120
# 40/40 [==============================] - 1s 15ms/step - loss: 9.1755e-04
# Epoch 110/120
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 111/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0011
# Epoch 112/120
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 113/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0012
# Epoch 114/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0011
# Epoch 115/120
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0011
# Epoch 116/120
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0011
# Epoch 117/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0010
# Epoch 118/120
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 4800 batches). You may need to use the repeat() function when building your dataset.
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0010

# %%
# Testing
predict_price = model.predict(x_test)
# predict_price = scala_y.inverse_transform(predict_price)
# y_train_price = scala_y.inverse_transform(y_train)

# error = pd.concat([pd.DataFrame(predict_price,columns=['predict_price'],index=None), pd.DataFrame(y_train_price,columns=['y_train_price'],index=None)], axis=1)
# error['error_price'] = error['predict_price'] - error['y_train_price']
# print(error)
# Out:
# 15/15 [==============================] - 4s 4ms/step

# %%
predict_price = model.predict(x_test)
print(predict_price)
# Out:
# 15/15 [==============================] - 0s 5ms/step
# [[0.42009842]
#  [0.42708924]
#  [0.42711735]
#  [0.44656998]
#  [0.44436523]
#  [0.4154019 ]
#  [0.4299961 ]
#  [0.43075767]
#  [0.40422937]
#  [0.40579382]
#  [0.41726074]
#  [0.41113022]
#  [0.40834957]
#  [0.41719624]
#  [0.4253264 ]
#  [0.45314884]
#  [0.48688814]
#  [0.5065862 ]
#  [0.5383138 ]
#  [0.5057861 ]
#  [0.5037234 ]
#  [0.50379944]
#  [0.5067092 ]
#  [0.47477028]
#  [0.4517329 ]
#  [0.45278272]
#  [0.44697848]
#  [0.45293823]
#  [0.45531502]
#  [0.43832314]
#  [0.4365439 ]
#  [0.4079816 ]
#  [0.4016141 ]
#  [0.39417028]
#  [0.38391373]
#  [0.38314205]
#  [0.36972174]
#  [0.38208142]
#  [0.40134642]
#  [0.3889514 ]
#  [0.39162365]
#  [0.39565903]
#  [0.39586034]
#  [0.38785   ]
#  [0.3826725 ]
#  [0.37317166]
#  [0.36999327]
#  [0.32824916]
#  [0.29651797]
#  [0.3103245 ]
#  [0.29424617]
#  [0.29833734]
#  [0.30488363]
#  [0.28300005]
#  [0.29053873]
#  [0.29245776]
#  [0.28412643]
#  [0.28568417]
#  [0.2923345 ]
#  [0.28103858]
#  [0.28010753]
#  [0.30907997]
#  [0.3196923 ]
#  [0.3316788 ]
#  [0.41741416]
#  [0.46049505]
#  [0.4787116 ]
#  [0.4717509 ]
#  [0.4344093 ]
#  [0.45466405]
#  [0.44152436]
#  [0.43605056]
#  [0.45407447]
#  [0.4417063 ]
#  [0.41471747]
#  [0.41159362]
#  [0.43098262]
#  [0.40689787]
#  [0.3819855 ]
#  [0.3699957 ]
#  [0.37052423]
#  [0.353981  ]
#  [0.38938808]
#  [0.38302892]
#  [0.36829892]
#  [0.39442503]
#  [0.40018192]
#  [0.39510316]
#  [0.38547254]
#  [0.36536595]
#  [0.3817579 ]
#  [0.3695776 ]
#  [0.3677677 ]
#  [0.36219633]
#  [0.38527876]
#  [0.3717103 ]
#  [0.40263724]
#  [0.40763417]
#  [0.39288083]
#  [0.3956164 ]
#  [0.3906862 ]
#  [0.40522495]
#  [0.40611336]
#  [0.40834418]
#  [0.42251405]
#  [0.41561335]
#  [0.43186638]
#  [0.43384784]
#  [0.43347093]
#  [0.4382463 ]
#  [0.43110147]
#  [0.43351385]
#  [0.44374153]
#  [0.45515913]
#  [0.44776168]
#  [0.44925076]
#  [0.43122533]
#  [0.42925176]
#  [0.4342016 ]
#  [0.4369655 ]
#  [0.42953756]
#  [0.4270507 ]
#  [0.40402183]
#  [0.40674326]
#  [0.3956566 ]
#  [0.39438903]
#  [0.39257237]
#  [0.3612437 ]
#  [0.36227873]
#  [0.3669549 ]
#  [0.36668426]
#  [0.3966493 ]
#  [0.39660668]
#  [0.3890549 ]
#  [0.3894344 ]
#  [0.39683926]
#  [0.38562524]
#  [0.37563074]
#  [0.36706477]
#  [0.3613723 ]
#  [0.3573727 ]
#  [0.344766  ]
#  [0.32562825]
#  [0.32214093]
#  [0.3192385 ]
#  [0.30258435]
#  [0.28963274]
#  [0.29129297]
#  [0.29471707]
#  [0.2903216 ]
#  [0.3078274 ]
#  [0.28240877]
#  [0.2822195 ]
#  [0.27267063]
#  [0.2640353 ]
#  [0.23246872]
#  [0.23194784]
#  [0.17991887]
#  [0.1540855 ]
#  [0.18201819]
#  [0.16932288]
#  [0.18249992]
#  [0.17440543]
#  [0.17594025]
#  [0.16789787]
#  [0.1651767 ]
#  [0.16582811]
#  [0.16132905]
#  [0.16574644]
#  [0.15881199]
#  [0.15517822]
#  [0.1568256 ]
#  [0.14948653]
#  [0.1459055 ]
#  [0.14741558]
#  [0.14907214]
#  [0.16547088]
#  [0.17028043]
#  [0.15771891]
#  [0.15830837]
#  [0.15241055]
#  [0.15046418]
#  [0.1544134 ]
#  [0.15828821]
#  [0.15798576]
#  [0.15615317]
#  [0.15620999]
#  [0.14914928]
#  [0.13620988]
#  [0.12745951]
#  [0.10959958]
#  [0.10779847]
#  [0.11776027]
#  [0.10391748]
#  [0.10822597]
#  [0.09737543]
#  [0.10612146]
#  [0.10586281]
#  [0.11142352]
#  [0.10591348]
#  [0.11460708]
#  [0.13653868]
#  [0.13152319]
#  [0.13254024]
#  [0.12796338]
#  [0.11994377]
#  [0.1141514 ]
#  [0.11235345]
#  [0.10835008]
#  [0.10593017]
#  [0.10911909]
#  [0.11075599]
#  [0.10979278]
#  [0.11428408]
#  [0.12035817]
#  [0.12231484]
#  [0.12170155]
#  [0.11239752]
#  [0.10611165]
#  [0.10396681]
#  [0.1079081 ]
#  [0.11168436]
#  [0.11635688]
#  [0.12438865]
#  [0.12388877]
#  [0.13427024]
#  [0.13615501]
#  [0.13305354]
#  [0.13266551]
#  [0.13079086]
#  [0.13050371]
#  [0.13116904]
#  [0.12248334]
#  [0.11748855]
#  [0.12882149]
#  [0.13688922]
#  [0.13641587]
#  [0.15019833]
#  [0.14566424]
#  [0.14400586]
#  [0.14035766]
#  [0.13746014]
#  [0.13935678]
#  [0.14149493]
#  [0.13960831]
#  [0.14003073]
#  [0.14302193]
#  [0.1367401 ]
#  [0.1413012 ]
#  [0.14334208]
#  [0.14196384]
#  [0.14355955]
#  [0.1435325 ]
#  [0.14116636]
#  [0.14017005]
#  [0.14357157]
#  [0.13816951]
#  [0.1232018 ]
#  [0.11929624]
#  [0.12385058]
#  [0.12168212]
#  [0.12327141]
#  [0.12351823]
#  [0.12440431]
#  [0.12265469]
#  [0.11502843]
#  [0.11199808]
#  [0.11332324]
#  [0.11055584]
#  [0.11163207]
#  [0.11206362]
#  [0.11283946]
#  [0.11244877]
#  [0.11334345]
#  [0.11308922]
#  [0.11097511]
#  [0.11413392]
#  [0.11733169]
#  [0.12794676]
#  [0.12887044]
#  [0.12839547]
#  [0.13023055]
#  [0.1179729 ]
#  [0.11999233]
#  [0.11479453]
#  [0.12645689]
#  [0.13805623]
#  [0.13442908]
#  [0.14204247]
#  [0.16017531]
#  [0.1542771 ]
#  [0.20092781]
#  [0.22109982]
#  [0.21211132]
#  [0.22033128]
#  [0.20531696]
#  [0.19735265]
#  [0.18544757]
#  [0.2099903 ]
#  [0.20531175]
#  [0.20575634]
#  [0.1930954 ]
#  [0.19670002]
#  [0.20576698]
#  [0.21249878]
#  [0.2189673 ]
#  [0.23231378]
#  [0.23575851]
#  [0.24380703]
#  [0.22519948]
#  [0.21601512]
#  [0.21827567]
#  [0.20730351]
#  [0.21726863]
#  [0.20963249]
#  [0.20455016]
#  [0.2049302 ]
#  [0.2006083 ]
#  [0.1926312 ]
#  [0.19001889]
#  [0.191709  ]
#  [0.19648518]
#  [0.19713838]
#  [0.19049689]
#  [0.19313705]
#  [0.19618317]
#  [0.19476768]
#  [0.19820693]
#  [0.19945589]
#  [0.19350842]
#  [0.19403735]
#  [0.19398747]
#  [0.18905349]
#  [0.19026986]
#  [0.21670185]
#  [0.21355858]
#  [0.20445317]
#  [0.20137978]
#  [0.16559398]
#  [0.13116789]
#  [0.15304281]
#  [0.14658175]
#  [0.13952897]
#  [0.12688963]
#  [0.13575119]
#  [0.14952253]
#  [0.14116162]
#  [0.14522767]
#  [0.14648432]
#  [0.14725822]
#  [0.1340037 ]
#  [0.13158022]
#  [0.13685465]
#  [0.13970923]
#  [0.15260047]
#  [0.15841626]
#  [0.15510584]
#  [0.15618269]
#  [0.14928389]
#  [0.15401234]
#  [0.15899195]
#  [0.15503651]
#  [0.15231642]
#  [0.15087487]
#  [0.15163441]
#  [0.15070173]
#  [0.15062945]
#  [0.14602573]
#  [0.15184245]
#  [0.14949915]
#  [0.1487754 ]
#  [0.14690064]
#  [0.14714399]
#  [0.15092275]
#  [0.14700913]
#  [0.14297298]
#  [0.13163552]
#  [0.12873524]
#  [0.12816624]
#  [0.12216965]
#  [0.12524404]
#  [0.12299223]
#  [0.12387269]
#  [0.12869854]
#  [0.12766793]
#  [0.12448698]
#  [0.13400973]
#  [0.13516924]
#  [0.12982446]
#  [0.12223112]
#  [0.12104492]
#  [0.12054816]
#  [0.11935388]
#  [0.12199415]
#  [0.12058072]
#  [0.12368677]
#  [0.119843  ]
#  [0.12085422]
#  [0.12138787]
#  [0.12110245]
#  [0.12535843]
#  [0.12519737]
#  [0.13891143]
#  [0.13885829]
#  [0.14617655]
#  [0.15445605]
#  [0.14651193]
#  [0.15003671]
#  [0.14637223]
#  [0.14373653]
#  [0.14917241]
#  [0.16089007]
#  [0.1584259 ]
#  [0.15776424]
#  [0.17082441]
#  [0.16225384]
#  [0.16483088]
#  [0.16241589]
#  [0.163703  ]
#  [0.16355607]
#  [0.1656737 ]
#  [0.15761138]
#  [0.15969469]
#  [0.16277966]
#  [0.16323376]
#  [0.16359147]
#  [0.1646493 ]
#  [0.15743206]
#  [0.15476835]
#  [0.15847436]
#  [0.15635589]
#  [0.14960423]
#  [0.14600962]
#  [0.14648364]
#  [0.14344645]
#  [0.14009276]
#  [0.14318769]
#  [0.15400937]
#  [0.1482006 ]
#  [0.15243694]
#  [0.15259583]
#  [0.14945878]
#  [0.1532937 ]
#  [0.1496807 ]
#  [0.15086651]
#  [0.14911637]
#  [0.14399783]
#  [0.14227448]
#  [0.14339094]
#  [0.14261235]]

# %%
# predict_error = elasticnet.predict(predict_price)
# index=0
predict_price = scala_y.inverse_transform(predict_price)
# for error in predict_error:
#     predict_price[index]+=error
#     index+=1
# print(predict_price)

# %%
y_test = scala_y.inverse_transform(y_test)
plt.figure(figsize=(20,10))
plt.plot(y_test, color="red", label=f"Real xrp Prices")
plt.plot(predict_price[0:], color="blue", label=f"Predicted xrp Prices")
plt.title(f"xrp Prices")
plt.xlabel("Time (day)")
plt.ylabel("Stock Prices")
plt.ylim(bottom=0)
plt.legend()
plt.show()

# %% [markdown]
# TEST

# %%
mae = mean_absolute_error(y_test, predict_price)
mape = mean_absolute_percentage_error(y_test, predict_price)
mse = mean_squared_error(y_test, predict_price)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predict_price)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 0.03
# MAPE: 4.39%
# MSE: 0.00
# RMSE: 0.04
# R2: 0.96

# %%
# predict_price_test = model.predict(x_test)
# predict_price_test = scala_y.inverse_transform(predict_price_test)
# y_test = scala_y.inverse_transform(y_test)

# %%
# validate = []
# for predict in predict_price_test:
#     predict= elasticnet.predict(np.array([predict]).reshape(-1,1))[0]
#     validate.append(predict)
# df_predict = pd.concat([pd.DataFrame(predict_price_test,columns=['predict_price_test'],index=None), pd.DataFrame(y_test,columns=['y_test'],index=None)], axis=1)
# df_predict['final_predict'] = df_predict['predict_price_test'] + validate
# print(df_predict.to_csv('result.csv'))
