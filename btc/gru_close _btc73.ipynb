# %%
import pandas as pd
import datetime as dt
import numpy as np

from csv import writer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU
from keras.models import load_model

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('btc.csv')
print(df)
# Out:
#       Unnamed: 0 formatted_date          high           low          open  \
# 0              0     2019-01-01   3850.913818   3707.231201   3849.216309
# 1              1     2019-01-02   3947.981201   3817.409424   3931.048584
# 2              2     2019-01-03   3935.685059   3826.222900   3832.040039
# 3              3     2019-01-04   3865.934570   3783.853760   3851.973877
# 4              4     2019-01-05   3904.903076   3836.900146   3836.519043
# ...          ...            ...           ...           ...           ...
# 1515        1515     2023-02-24  24103.705078  23007.072266  23200.125000
# 1516        1516     2023-02-25  23210.210938  22861.558594  23174.150391
# 1517        1517     2023-02-26  23654.367188  23084.220703  23561.451172
# 1518        1518     2023-02-27  23857.890625  23205.878906  23521.837891
# 1519        1519     2023-02-28  23585.384766  23077.650391  23150.929688
#
#              close       volume      adjclose
# 0      3843.520020   4324200990   3843.520020
# 1      3943.409424   5244856836   3943.409424
# 2      3836.741211   4530215219   3836.741211
# 3      3857.717529   4847965467   3857.717529
# 4      3845.194580   5137609824   3845.194580
# ...            ...          ...           ...
# 1515  23198.126953  26811744928  23198.126953
# 1516  23175.375000  16100721565  23175.375000
# 1517  23561.212891  16644534842  23561.212891
# 1518  23522.871094  22660763494  23522.871094
# 1519  23147.353516  20535363434  23147.353516
#
# [1520 rows x 8 columns]

# %%
# Process data
df['H-L'] = df['high'] - df['low']
# df['O-C'] = df['open'] - df['close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
df[f'SMA_{ma_1}'] = df['close'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['close'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['close'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['close'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['close'].rolling(window=ma_3).std()
df.dropna(inplace=True)

# df.to_csv("/BOOSTING/bitcoin_processed_close.csv")
df
# Out:
#       Unnamed: 0 formatted_date          high           low          open  \
# 20            20     2019-01-21   3608.840820   3558.537109   3575.081299
# 21            21     2019-01-22   3620.746582   3539.721436   3605.557129
# 22            22     2019-01-23   3623.067871   3565.313965   3584.500244
# 23            23     2019-01-24   3616.087402   3569.092773   3607.390381
# 24            24     2019-01-25   3612.927734   3575.597412   3599.715332
# ...          ...            ...           ...           ...           ...
# 1515        1515     2023-02-24  24103.705078  23007.072266  23200.125000
# 1516        1516     2023-02-25  23210.210938  22861.558594  23174.150391
# 1517        1517     2023-02-26  23654.367188  23084.220703  23561.451172
# 1518        1518     2023-02-27  23857.890625  23205.878906  23521.837891
# 1519        1519     2023-02-28  23585.384766  23077.650391  23150.929688
#
#              close       volume      adjclose          H-L         SMA_7  \
# 20     3576.032471   5004347059   3576.032471    50.303711   3646.814279
# 21     3604.577148   5313623556   3604.577148    81.025146   3643.085972
# 22     3585.123047   5433755649   3585.123047    57.753906   3633.102574
# 23     3600.865479   5262869046   3600.865479    46.994629   3622.002790
# 24     3599.765869   5265847539   3599.765869    37.330322   3613.706578
# ...            ...          ...           ...          ...           ...
# 1515  23198.126953  26811744928  23198.126953  1096.632812  24224.126395
# 1516  23175.375000  16100721565  23175.375000   348.652344  24014.711775
# 1517  23561.212891  16644534842  23561.212891   570.146484  23905.221819
# 1518  23522.871094  22660763494  23522.871094   652.011719  23718.610770
# 1519  23147.353516  20535363434  23147.353516   507.734375  23534.467913
#
#             SMA_14        SMA_21        SD_7        SD_21
# 20     3705.745762   3776.614490   50.412745   165.766144
# 21     3675.297852   3765.236258   52.717606   169.110917
# 22     3643.142613   3748.175002   56.560870   168.308098
# 23     3637.566964   3736.942825   53.704202   169.964561
# 24     3631.309849   3724.659412   51.693454   170.120767
# ...            ...           ...         ...          ...
# 1515  23553.841936  23260.729632  536.387413  1085.510059
# 1516  23647.020508  23253.278553  625.186896  1085.534512
# 1517  23773.664062  23282.114118  628.353819  1085.276291
# 1518  23896.147600  23318.436105  486.099617  1079.681956
# 1519  23962.329660  23312.867653  406.525334  1080.276560
#
# [1500 rows x 14 columns]

# %%
pre_day =7
scala_x = MinMaxScaler(feature_range=(0,1))
scala_y = MinMaxScaler(feature_range=(0,1))
cols_x = ['high','low','open','H-L', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['close']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))

x_total = []
y_total = []

for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])

# test_size = (int)(len(scaled_data_y) * 0.2)
# print(test_size)

# x_train = np.array(x_total[:len(x_total)])
# # x_test = np.array(x_total[len(x_total)-test_size:])
# y_train = np.array(y_total[:len(y_total)])
# # y_test = np.array(y_total[len(y_total)-test_size:])

test_size = (int)(len(scaled_data_y) * 0.2)
print(test_size)

x_train = np.array(x_total[:len(x_total)-test_size])
x_test = np.array(x_total[len(x_total)-test_size:])
y_train = np.array(y_total[:len(y_total)-test_size])
y_test = np.array(y_total[len(y_total)-test_size:])



print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# 300
# (1193, 7, 9) (1193, 1) (300, 7, 9) (300, 1)

# %%
# Build model
model = Sequential()

model.add(GRU(units=60, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=120, steps_per_epoch=40, use_multiprocessing=True)
# model.save("../../model/BOOSTING/GRU_boosting_close.h5")
# Out:
# Epoch 1/120
# 40/40 [==============================] - 24s 20ms/step - loss: 0.0295
# Epoch 2/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0065
# Epoch 3/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0049
# Epoch 4/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0046
# Epoch 5/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 6/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0039
# Epoch 7/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0036
# Epoch 8/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0035
# Epoch 9/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0032
# Epoch 10/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0036
# Epoch 11/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0037
# Epoch 12/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0034
# Epoch 13/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0033
# Epoch 14/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0028
# Epoch 15/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0028
# Epoch 16/120
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0026
# Epoch 17/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0026
# Epoch 18/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0027
# Epoch 19/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0026
# Epoch 20/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0030
# Epoch 21/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0027
# Epoch 22/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0029
# Epoch 23/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0024
# Epoch 24/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0026
# Epoch 25/120
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0021
# Epoch 26/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0023
# Epoch 27/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0020
# Epoch 28/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0025
# Epoch 29/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0025
# Epoch 30/120
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0027
# Epoch 31/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0028
# Epoch 32/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0024
# Epoch 33/120
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 34/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0022
# Epoch 35/120
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0019
# Epoch 36/120
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0021
# Epoch 37/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0021
# Epoch 38/120
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0021
# Epoch 39/120
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0022
# Epoch 40/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0024
# Epoch 41/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0021
# Epoch 42/120
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0019
# Epoch 43/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0018
# Epoch 44/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0020
# Epoch 45/120
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0021
# Epoch 46/120
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0018
# Epoch 47/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0019
# Epoch 48/120
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0019
# Epoch 49/120
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0019
# Epoch 50/120
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0031
# Epoch 51/120
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018
# Epoch 52/120
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 53/120
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016
# Epoch 54/120
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0016
# Epoch 55/120
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0020
# Epoch 56/120
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018
# Epoch 57/120
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017
# Epoch 58/120
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018
# Epoch 59/120
# 40/40 [==============================] - 1s 38ms/step - loss: 0.0016
# Epoch 60/120
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0016
# Epoch 61/120
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0020
# Epoch 62/120
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017
# Epoch 63/120
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0015
# Epoch 64/120
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 65/120
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0019
# Epoch 66/120
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0015
# Epoch 67/120
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0023
# Epoch 68/120
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 69/120
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 70/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0017
# Epoch 71/120
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0017
# Epoch 72/120
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0014
# Epoch 73/120
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0022
# Epoch 74/120
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0020
# Epoch 75/120
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0016
# Epoch 76/120
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0016
# Epoch 77/120
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0016
# Epoch 78/120
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0014
# Epoch 79/120
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0015
# Epoch 80/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0016
# Epoch 81/120
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0014
# Epoch 82/120
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0014
# Epoch 83/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0014
# Epoch 84/120
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0014
# Epoch 85/120
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0014
# Epoch 86/120
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0014
# Epoch 87/120
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0015
# Epoch 88/120
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0017
# Epoch 89/120
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0013
# Epoch 90/120
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0015
# Epoch 91/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0019
# Epoch 92/120
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0015
# Epoch 93/120
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0015
# Epoch 94/120
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016
# Epoch 95/120
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0013
# Epoch 96/120
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0014
# Epoch 97/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0016
# Epoch 98/120
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0015
# Epoch 99/120
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0014
# Epoch 100/120
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 101/120
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0014
# Epoch 102/120
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0014
# Epoch 103/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0014
# Epoch 104/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0013
# Epoch 105/120
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0013
# Epoch 106/120
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0014
# Epoch 107/120
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0014
# Epoch 108/120
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0013
# Epoch 109/120
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0013
# Epoch 110/120
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017
# Epoch 111/120
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0013
# Epoch 112/120
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0013
# Epoch 113/120
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0016
# Epoch 114/120
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 115/120
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0014
# Epoch 116/120
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 117/120
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0014
# Epoch 118/120
# 40/40 [==============================] - 2s 36ms/step - loss: 0.0014
# Epoch 119/120
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0014
# Epoch 120/120
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0014

# %%
# Testing
predict_price = model.predict(x_test)
# predict_price = scala_y.inverse_transform(predict_price)
# y_train_price = scala_y.inverse_transform(y_train)

# error = pd.concat([pd.DataFrame(predict_price,columns=['predict_price'],index=None), pd.DataFrame(y_train_price,columns=['y_train_price'],index=None)], axis=1)
# error['error_price'] = error['predict_price'] - error['y_train_price']
# print(error)
# Out:
# 10/10 [==============================] - 42s 6ms/step

# %%
# predict_error = elasticnet.predict(predict_price)
# index=0
predict_price = scala_y.inverse_transform(predict_price)
# for error in predict_error:
#     predict_price[index]+=error
#     index+=1
# print(predict_price)

# %%
y_test = scala_y.inverse_transform(y_test)
plt.figure(figsize=(20,10))
plt.plot(y_test, color="red", label=f"Real BTC Prices")
plt.plot(predict_price[0:], color="blue", label=f"Predicted BTC Prices")
plt.title(f"BTC Prices")
plt.xlabel("Time (day)")
plt.ylabel("Stock Prices")
plt.ylim(bottom=0)
plt.legend()
plt.show()

# %% [markdown]
# TEST

# %%
mae = mean_absolute_error(y_test, predict_price)
mape = mean_absolute_percentage_error(y_test, predict_price)
mse = mean_squared_error(y_test, predict_price)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predict_price)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 956.93
# MAPE: 4.31%
# MSE: 1394672.22
# RMSE: 1180.96
# R2: 0.92

# %%
# predict_price_test = model.predict(x_test)
# predict_price_test = scala_y.inverse_transform(predict_price_test)
# y_test = scala_y.inverse_transform(y_test)

# %%
# validate = []
# for predict in predict_price_test:
#     predict= elasticnet.predict(np.array([predict]).reshape(-1,1))[0]
#     validate.append(predict)
# df_predict = pd.concat([pd.DataFrame(predict_price_test,columns=['predict_price_test'],index=None), pd.DataFrame(y_test,columns=['y_test'],index=None)], axis=1)
# df_predict['final_predict'] = df_predict['predict_price_test'] + validate
# print(df_predict.to_csv('result.csv'))
